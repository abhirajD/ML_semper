# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = pd.read_csv('PythonData/SVM-radial.csv', header=0)
plt.scatter(data.iloc[:,0], data.iloc[:,1])
plt.show()

# %%
# Let's try to cluster with HCLust - we will only use the first two variables
dataClust = data.iloc[:,0:2]

# %%
dataClust.head()
# Out:
#           X         Y
# 0 -0.443114 -0.350086
# 1  1.538914  0.699601
# 2  0.340098  0.165058
# 3  0.375362 -1.477017
# 4 -0.355572  0.292761

# %%
# We will use Agglomerative clustering ...
from sklearn.cluster import AgglomerativeClustering

# %%
# Here we instantiate the model; we will use the defaults, namely two clusters, Ward linkage ...
model = AgglomerativeClustering()

# %%
# Now we find the clusters ...
model.fit(dataClust)
# Out:
# AgglomerativeClustering(affinity='euclidean', compute_full_tree='auto',
#             connectivity=None, linkage='ward', memory=None, n_clusters=2,
#             pooling_func=<function mean at 0x000001C87A6DF510>)

# %%
plt.scatter(dataClust.iloc[:, 0], dataClust.iloc[:, 1], c=model.labels_,)
plt.show()

# %%
# Not so good. Let's try another one ...
from sklearn.datasets.samples_generator import make_blobs
X, y_true = make_blobs(n_samples=300, centers=4,
                       cluster_std=0.60, random_state=0)
plt.scatter(X[:, 0], X[:, 1], s=50);
plt.show()

# %%
model = AgglomerativeClustering(n_clusters=4)

# %%
model.fit(X)
# Out:
# AgglomerativeClustering(affinity='euclidean', compute_full_tree='auto',
#             connectivity=None, linkage='ward', memory=None, n_clusters=4,
#             pooling_func=<function mean at 0x000001C87A6DF510>)

# %%
plt.scatter(X[:, 0], X[:, 1], c=model.labels_,)
plt.show()

# %%
# Much better!
model.fit_predict(X)
# Out:
# array([2, 0, 1, 0, 2, 2, 3, 1, 0, 0, 3, 0, 1, 0, 2, 1, 1, 2, 3, 3, 2, 2, 1,
#        3, 3, 1, 2, 1, 3, 1, 0, 0, 1, 0, 0, 0, 0, 0, 3, 2, 1, 3, 1, 1, 3, 3,
#        0, 3, 0, 2, 3, 2, 0, 2, 2, 3, 0, 3, 0, 2, 0, 1, 0, 3, 3, 3, 0, 2, 0,
#        3, 1, 3, 0, 3, 3, 0, 3, 1, 2, 0, 2, 1, 2, 2, 0, 1, 2, 1, 0, 0, 1, 2,
#        0, 3, 3, 1, 2, 2, 1, 3, 0, 2, 0, 2, 1, 2, 2, 1, 0, 1, 3, 3, 2, 0, 2,
#        1, 0, 2, 2, 1, 3, 2, 3, 2, 2, 2, 2, 3, 2, 3, 0, 3, 3, 2, 0, 3, 3, 0,
#        1, 0, 0, 3, 1, 3, 1, 3, 0, 1, 0, 0, 0, 1, 0, 1, 2, 3, 0, 3, 2, 1, 0,
#        1, 1, 2, 1, 3, 3, 1, 2, 1, 1, 0, 2, 1, 3, 0, 2, 2, 1, 3, 2, 1, 3, 3,
#        1, 1, 1, 1, 2, 0, 1, 3, 1, 1, 3, 3, 3, 1, 3, 0, 1, 3, 2, 3, 1, 0, 3,
#        0, 1, 0, 1, 3, 1, 1, 0, 3, 3, 2, 2, 1, 0, 2, 2, 3, 2, 3, 1, 0, 0, 1,
#        1, 0, 1, 2, 3, 1, 2, 3, 0, 3, 2, 1, 2, 0, 0, 0, 0, 3, 3, 0, 1, 3, 2,
#        1, 3, 3, 3, 2, 2, 0, 1, 1, 3, 2, 0, 3, 1, 0, 1, 2, 2, 3, 3, 1, 2, 2,
# ...
